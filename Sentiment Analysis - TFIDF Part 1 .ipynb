# %%
#list of restaurants top 50 list
restaurants = [
'Arendsnest Dutch Beer Bar'
,'Bakers & Roasters'
,'Biercafe Gollem'
,'Bird Thai Snackbar'
,"Bord'Eau"
,'Brasserie Ambassade'
,'Brasserie SenT'
,'Brasserie Vlaming - Amsterdam'
,'Broodje Bert'
,'Bussia'
,'Casa Nostra'
,'Ciel Bleu Restaurant'
,'Daalder'
,'De Drie Graefjes'
,'De Silveren Spiegel'
,'de Struisvogel'
,'Eatmosfera Ristorante'
,'Eetcafe Singel 404'
,'Gartine'
,'Greenwoods'
,'Greenwoods Keizersgracht'
,'Guts & Glory'
,'Ivy & Bros'
,'Jacketz Oud-West'
,'Kinnaree Thai Cuisine'
,'La Zoccola del Pacioccone Pizzeria'
,"Lombardo's"
,'MAX Amsterdam'
,'Omelegg - City Centre'
,'Omelegg - De Pijp'
,'Pannenkoekenhuis Upstairs'
,'PIQNIQ'
,'Restaurant Adam'
,'Restaurant Cote Ouest'
,'Restaurant Johannes'
,'Restaurant Luna'
,'Restaurant Mandarijn'
,'Rijks'
,'Senses Restaurant'
,'Taj Indian'
,'Teppanyaki Restaurant Sazanka'
,'The Lobby Nesplein Restaurant & Bar'
,'The Pantry'
,'The Seafood Bar'
,'Van Kerkwijk'
,'Vinkeles'
,'Vlaming eten & drinken'
,'Winkel 43'
,"Zaza's"
]

# %%
#Merging top 50 all restaurant data 

import glob
import pandas as pd

# get data file names
path =r"C:/Users/YESIM/Desktop/TEXT MINING PROJECT/AMSTERDAM/RESTAURANTS/Top 50"
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, error_bad_lines=False) )

# Concatenate all data into one DataFrame
df = pd.concat(dfs, ignore_index=True)

df
# Out:
# b'Skipping line 4: expected 5 fields, saw 6\nSkipping line 5: expected 5 fields, saw 6\nSkipping line 6: expected 5 fields, saw 6\nSkipping line 11: expected 5 fields, saw 6\nSkipping line 12: expected 5 fields, saw 6\nSkipping line 26: expected 5 fields, saw 6\nSkipping line 29: expected 5 fields, saw 6\nSkipping line 37: expected 5 fields, saw 6\nSkipping line 46: expected 5 fields, saw 6\nSkipping line 55: expected 5 fields, saw 6\nSkipping line 66: expected 5 fields, saw 6\nSkipping line 68: expected 5 fields, saw 6\nSkipping line 77: expected 5 fields, saw 6\nSkipping line 88: expected 5 fields, saw 6\nSkipping line 96: expected 5 fields, saw 6\nSkipping line 113: expected 5 fields, saw 6\nSkipping line 114: expected 5 fields, saw 6\nSkipping line 115: expected 5 fields, saw 6\nSkipping line 116: expected 5 fields, saw 6\nSkipping line 121: expected 5 fields, saw 6\nSkipping line 124: expected 5 fields, saw 6\nSkipping line 143: expected 5 fields, saw 6\nSkipping line 153: expected 5 fields, saw 6\nSkipping line 154: expected 5 fields, saw 6\nSkipping line 163: expected 5 fields, saw 6\nSkipping line 165: expected 5 fields, saw 6\nSkipping line 174: expected 5 fields, saw 6\nSkipping line 177: expected 5 fields, saw 6\nSkipping line 183: expected 5 fields, saw 6\nSkipping line 184: expected 5 fields, saw 6\nSkipping line 185: expected 5 fields, saw 6\nSkipping line 186: expected 5 fields, saw 6\nSkipping line 198: expected 5 fields, saw 6\nSkipping line
 5 fields, saw 6\nSkipping line 188: expected 5 fields, saw 6\nSkipping line 190: expected 5 fields, saw 6\nSkipping line 194: expected 5 fields, saw 6\nSkipping line 199: expected 5 fields, saw 6\nSkipping line 205: expected 5 fields, saw 6\nSkipping line 217: expected 5 fields, saw 6\nSkipping line 219: expected 5 fields, saw 6\nSkipping line 221: expected 5 fields, saw 6\nSkipping line 225: expected 5 fields, saw 6\nSkipping line 227: expected 5 fields, saw 6\n'
#                                                    title  \
# 0                               Beers... So much choice!
# 1           Nice place, great selection but slow service
# 2                       Fantastic beer and a great night
# 3                           It's not #1 for nothing.....
# 4                               Great bar on Herengracht
# 5                                          Amazing place
# 6                                            Dutch beers
# 7                                           Good evening
# 8                                        a very nice bar
# 9      SURELY A BEER FOR ALL TASTES IN LOVELY BAR, WI...
# 10                                Nice cheese great beer
# 11                      There's no better place for beer
# 12                  Worth the walk,great choice in beers
# 13                           Great Bar to try Dutch Beer
# 14                                  Great bar; good beer
# 15     Let's be be original: great food, good service...
# 16     If you're a fan of great beer and want to expe...
# 17                                Great choice of beers!
# 18                   Wonderful selection of Dutch beers.
# 19                                Amazing beer selection
# 20                               Amazing beer selection!
# 21      Our favorite Dutch Special Beer Bar in Amsterdam
# 22       Peaceful bar by the canal with exceptional beer
# 23                  My favorite "go to" pub in Amsterdam
# 24                   Comfort, Beer and Good Conversation
# 25           Thumbs up for dutch beer and friendly staff
# 26                              Great beers and service!
# 27                                          Awesome bar!
# 28                                   Good recommendation
# 29                                             Great Bar
# ...                                                  ...
# 11658                          wonderful and well priced
# 11659                                  Excellent Service
# 11660                                 Starter was great!
# 11661                         fully met our expectations
# 11662                  Where to eat if from U.S.A..?....
# 11663                       good food, reasonable prices
# 11664                   Fantastic night out, great food.
# 11665                                 Elegant and classy
# 11666        Exactly as all the reviews before- go there
# 11667                       Attentive Thoughtful Service
# 11668                  A great ambiance for a great meal
# 11669                            You Won't Go Wrong Here
# 11670                               So Rare in Amsterdam
# 11671                        An absolute must for dinner
# 11672          Excellent restaurant, very friendly staff
# 11673                                             GREAT!
# 11674              Our favorite restaurant in Amsterdam!
# 11675                          Incredible meal, MUST GO!
# 11676   Good food at a good price in a great environment
# 11677                                 You must eat here!
# 11678                                 One word "Amazing"
# 11679                                     Loved our stay
# 11680  Perfection... And that is something I rarely say.
# 11681                          A must when in Amsterdam!
# 11682        Foodlovers are welcome close to Albert Cuyp
# 11683                                  Worth every cent!
# 11684                              Very good experience.
# 11685                                     EXCELLENT MEAL
# 11686                                            Amazing
# 11687                     Absolutely stunning throughout
#
#                                                   review         stars  \
# 0      We found this out of chance but realised it wa...  5 of 5 stars
# 1      I'm a great fan of craft beer so after seeing ...  4 of 5 stars
# 2      Had a fantastic night in this bar on our first...  5 of 5 stars
# 3      Wanted to go here as it is rated #1 on tripadv...  5 of 5 stars
# 4      Visited a couple of times during a recent trip...  5 of 5 stars
# 5      Small place with a loooot of good beers. The g...  5 of 5 stars
# 6      Here you can find a lot of good different beer...  5 of 5 stars
# 7      Fab selection of beers. A little pricier than ...  4 of 5 stars
# 8      We did tasting in this bar, there is a huge va...  4 of 5 stars
# 11686  Went to this restaurant for boyfriends birthda...  5 of 5 stars
# 11687  Restaurant was stunning, atmosphere warm & cos...  5 of 5 stars
#
#                  review_count         help_count
# 0       21 restaurant reviews   19 helpful votes
# 1       57 restaurant reviews   66 helpful votes
# 2        3 restaurant reviews    6 helpful votes
# 3       16 restaurant reviews   16 helpful votes
# 4        3 restaurant reviews                NaN
# 5       46 restaurant reviews   12 helpful votes
# 6       33 restaurant reviews    4 helpful votes
# 7        6 restaurant reviews   16 helpful votes
# 8       19 restaurant reviews   10 helpful votes
# 9       70 restaurant reviews   76 helpful votes
# 10       7 restaurant reviews    2 helpful votes
# 11      56 restaurant reviews   17 helpful votes
# 12                        NaN    4 helpful votes
# 13       6 restaurant reviews   13 helpful votes
# 14      38 restaurant reviews   67 helpful votes
# 15     131 restaurant reviews  101 helpful votes
# 16      25 restaurant reviews   25 helpful votes
# 17      31 restaurant reviews   28 helpful votes
# 18      14 restaurant reviews    3 helpful votes
# 19       4 restaurant reviews    2 helpful votes
# 20       4 restaurant reviews     1 helpful vote
# 21     102 restaurant reviews   51 helpful votes
# 22     158 restaurant reviews   85 helpful votes
# 23     218 restaurant reviews   95 helpful votes
# 24      52 restaurant reviews   49 helpful votes
# 25       3 restaurant reviews     1 helpful vote
# 26                        NaN    2 helpful votes
# 27       3 restaurant reviews    7 helpful votes
# 28                        NaN     1 helpful vote
# 29      44 restaurant reviews   34 helpful votes
# ...                       ...                ...
# 11658    8 restaurant reviews    6 helpful votes
# 11659    5 restaurant reviews    3 helpful votes
# 11660   17 restaurant reviews    9 helpful votes
# 11661   32 restaurant reviews   30 helpful votes
# 11662   39 restaurant reviews   62 helpful votes
# 11663   45 restaurant reviews  117 helpful votes
# 11664                     NaN    2 helpful votes
# 11665   42 restaurant reviews   15 helpful votes
# 11666   47 restaurant reviews   87 helpful votes
# 11667   14 restaurant reviews   12 helpful votes
# 11668   37 restaurant reviews   40 helpful votes
# 11669   46 restaurant reviews   26 helpful votes
# 11670   44 restaurant reviews   22 helpful votes
# 11671                     NaN     1 helpful vote
# 11672   13 restaurant reviews    5 helpful votes
# 11673    8 restaurant reviews   17 helpful votes
# 11674   10 restaurant reviews    4 helpful votes
# 11675   29 restaurant reviews   95 helpful votes
# 11676   23 restaurant reviews   18 helpful votes
# 11677   44 restaurant reviews   41 helpful votes
# 11678                     NaN                NaN
# 11679                     NaN    5 helpful votes
# 11680    3 restaurant reviews    2 helpful votes
# 11681    3 restaurant reviews    2 helpful votes
# 11682   10 restaurant reviews    3 helpful votes
# 11683                     NaN                NaN
# 11684    6 restaurant reviews                NaN
# 11685    4 restaurant reviews    3 helpful votes
# 11686                     NaN                NaN
# 11687    4 restaurant reviews    3 helpful votes
#
# [11688 rows x 5 columns]

# %%
#Data Preparation

import numpy as np 

df = df.fillna(value=str(0))

df["full_text"] = df["title"] + ". " + df["review"]

#Reviews with 3 stars or lower are negative sentiment and others are positive sentiment 
def get_class(stars):
    score = int(stars[0])
    if score > 3:
        return 1
    else:
        return 0

def review_count(review_count):
    return review_count[0]

def help_count(help_count):
    return help_count[0]

def del_more(full_text):
    if full_text[-1] == "e" and full_text[-2] == "r" and full_text[-3] == "o" and full_text[-4] == "M":
        return full_text[0:-8]
    else:
        return full_text
    
df["review count"] = df["review_count"].apply(review_count).astype(int)
df["help count"] = df["help_count"].apply(help_count).astype(int)
df["sentiment"] = df["stars"].apply(get_class)
df["id"] = range(0,len(df))
df["full_text"] = df["full_text"].apply(del_more)

df_sent = df[["full_text", "sentiment"]]

df_sent.tail()
# Out:
#                                                full_text  sentiment
# 11683  Worth every cent!. Went a little out of the ce...          1
# 11684  Very good experience.. We had a amazing night ...          1
# 11685  EXCELLENT MEAL. Have been here before two year...          1
# 11686  Amazing. Went to this restaurant for boyfriend...          1
# 11687  Absolutely stunning throughout. Restaurant was...          1

# %% [markdown]
# Bag of Words Method / Python Machine Learning Book
#
# 1) Bag of Words are the individual words in the collection of documents.
# 2) TF-IDF Term Freq Inverse Document Frequency is applied to detect often used common words such as 'and' or 'the'.
#
# IMPORTANT NOTE:
# Observations for Class 0 - Negative Sentiment Restaurant Reviews may not be enough to fit test data well.
# Therefore True Negatives are relatively low compared to True Positives.
# We will collect more negative sentiment reviews in the next stage in order to boost True Negative Performance.

# %%
#Bag of Words Method / Python Machine Learning Book

#Preprocess text data get rid of punctuations, deal with emoticons, capital letters and delete html markups by using regular expressions library
import re
def preprocess(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    text = re.sub('[\W]+', ' ', text.lower()) + ''.join(emoticons).replace('-', '')
    
    return text
df_sent["full_text"] = df["full_text"].apply(preprocess)

#Tokenizing documents via Porter Stemmer Algorithm
def tokenizer(text):
    return text.split()
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

#Remove stop words

from nltk.corpus import stopwords
stop = stopwords.words("english")

#Splitting data into training and test sets
X = df_sent["full_text"].values
y = df_sent["sentiment"].values
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.33, random_state=1)

#Train Model for sentiment analysis and evaluation
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer


tfidf = TfidfVectorizer(strip_accents=None,
    lowercase=False,
    preprocessor=None, stop_words = None, ngram_range = (1,1), tokenizer = tokenizer)

lr_tfidf = Pipeline([('vect', tfidf),
                     ('clf',
    LogisticRegression(random_state=0, C=10.0, penalty = "l2"))])

lr_tfidf.fit_transform(X_train, y_train)
pred = lr_tfidf.predict(X_test)
Accuracy = lr_tfidf.score(X_test, y_test)

from sklearn.metrics import average_precision_score, recall_score

precision = average_precision_score(y_test, pred)
recall = recall_score(y_test, pred)
from sklearn.metrics import f1_score
f_score = f1_score(y_test, pred, average = "micro")

print("Accuracy: %f\nPrecision: %f\nRecall: %f\nF1 score(micro): %f" %(Accuracy, precision ,recall, f_score))
TN_Ratio = 1 - (np.sum(pred[y_test == 0])/len(pred[y_test == 0]))
print("TN/(TN+FN): %f -- This is due to underfitting and low obs. of negative reviews." %TN_Ratio )
# Out:
# C:\Users\YESIM\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\YESIM\Anaconda3\lib\site-packages\sklearn\utils\__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Accuracy: 0.956713
# Precision: 0.979943
# Recall: 0.995319
# F1 score(micro): 0.977423
# TN/(TN+FN): 0.336283 -- This is due to underfitting and low obs. of negative reviews.
# C:\Users\YESIM\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:976: DeprecationWarning: From version 0.18, binary input will not be handled specially when using averaged precision/recall/F-score. Please use average='binary' to report only the positive class performance.
#   'positive class performance.', DeprecationWarning)

# %%
len(y[y==0])/len(y)
# Out:
# 0.05655373032169747
